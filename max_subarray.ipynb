# %%
nums =[-2,-1]

# %%
max_sum = float('-inf')
temp_sum = 0

if len(nums) == 1:
    print(nums[0])

for num in nums:
    temp_sum += num

    max_sum = max(max_sum, temp_sum)

    if temp_sum < 0:
        temp_sum = 0

# %%
print(max_sum)
# Out:
# -1
