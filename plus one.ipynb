# %%
digits = [9,7]

# %%
temp = ""

for digit in digits:
    temp += str(digit)

print(temp)
# Out:
# 97

# %%
temp = int(temp) +1
print(temp)
# Out:
# 98

# %%
# if(digits[0] == 9):
#     ret = [""] * (len(digits)+1)
# else:    
#     ret = [""] * (len(digits))

ret =[]
i = len(ret) -1
# i = 0


while (temp !=0):
    rem = int(temp % 10)
    # print(rem)
    temp = temp// 10
    # ret[i] = rem
    
    ret.insert(i, rem)
    i -= 1

# %%
ret
# Out:
# [9, 8]

# %%
digits = [9,8,7,8,6]

# %%
n = len(digits)

for i in range(n - 1, -1, -1):
    if digits[i] == 9:
        digits[i] = 0
    else:
        digits[i]+= 1
        print( digits)

print( [1] + [0] * n)
# Out:
# [9, 8, 7, 8, 7]
# [9, 8, 7, 9, 7]
# [9, 8, 8, 9, 7]
# [9, 9, 8, 9, 7]
# [1, 0, 0, 0, 0, 0]
