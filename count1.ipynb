# %%
n = 5

# %%
tc = 0
for i in range(1, n+1):
    tc = 0
    while i!= 0:
        rem = i % 2
        # print("rem", rem)
        i = i// 2
        # print("i", i)
        if rem == 1:
            tc += 1
            # print("tc", tc)
    # tc = 0
    
    print("ret",tc)
# Out:
# ret 1
# ret 1
# ret 2
# ret 1
# ret 2
