# %%
nums = [1,2,1]

# %%
n = len(nums)
print(n)
ans = [0] * ((n * 2))
print(len(ans))

for i in range(len(nums)):
    t = nums[i]
    ans[i] = t
    ans[i+n] = nums[i]

print(ans)
# Out:
# 3
# 6
# [1, 2, 1, 1, 2, 1]
