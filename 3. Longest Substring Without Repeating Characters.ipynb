# %%
s = "pwwkew"
len(s)
# Out:
# 6

# %%
maxi = 0
my_dict = {}
l = r = 0

while r < len(s): 
    
    if s[r] in my_dict:
        l = max(l, my_dict[s[r]] + 1)
    
    my_dict[s[r]] = r
    maxi = max(maxi,r-l+1)
    r += 1
    
print(maxi)
# Out:
# 3

# %%
my_dict
# Out:
# {'w': 2, 'k': 1, 'e': 1}
